# %% [markdown]
# # Manejo de archivos - pandas - json - file

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/ods_1_2.csv")

# %%
data
# Out:
#                     id_str        from_user  \
# 0      1144191403557347329       osalanEJGV
# 1      1144190858163576832       CEAinforma
# 2      1144190759597498369  Plataforma3sect
# 3      1144190694053036032  Plataforma3sect
# 4      1144190578554540034      CesarNandis
# ...                    ...              ...
# 18496  1134819048028495872        quiroz979
# 18497  1134819030307680256       gramontani
# 18498  1134818548902236160  MatiasL14340413
# 18499  1134818540912091136       gramontani
# 18500  1134818135918469120  MatiasL14340413
#
#                                                     text  \
# 0      RT @LoliRicoG: Durante #Prevencia2019 tuve el ...
# 1      RT @Adolfo_Borrero: Javier González De Lara, P...
# 2      RT @Mesa3sectorAst: Los #ODS son una iniciativ...
# 3      RT @Mesa3sectorAst: Con la marcación de la cas...
# 4      RT @Agenda2030MX: Los 17 #ODS de la #Agenda203...
# ...                                                  ...
# ...

# %%
data2 = data[['id_str', 'entities_str']]

# %%
lista = data2.to_dict('records')
lista
# Out:
# [{'id_str': '1144191403557347329',
#   'entities_str': '{"hashtags":[{"text":"Prevencia2019","indices":[23,37]}],"symbols":[],"user_mentions":[{"screen_name":"LoliRicoG","name":"Dolores Rico Garcia","id":1484933762,"id_str":"1484933762","indices":[3,13]},{"screen_name":"ginariano","name":"Gina Riaño","id":413536351,"id_str":"413536351","indices":[67,77]},{"screen_name":"OissSec","name":"OISS","id":718032769771810800,"id_str":"718032769771810818","indices":[103,111]}],"urls":[]}'},
#  {'id_str': '1144190858163576832',
# ...

# %%
import json
# Solución 1:

lista2 = []
for l in lista:
    try:
        lista2.append({'id_str': l['id_str'], 'entities_str': json.loads(l['entities_str'])})
    except:
        print(l)
print(lista2)

# Solución 2:
# usando listas compresas
lista3 = [{'id_str': l['id_str'], 'entities_str': json.loads(l['entities_str'])} for l in lista \
          if l['entities_str'].__class__ is str]
# Out:
# {'id_str': '1137370030553935872', 'entities_str': nan}
# {'id_str': 'https://t.co/kcgJZ4oct3 vía @notgip | #ODS #FuturoSostenible', 'entities_str': nan}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(len(lista2))
print(len(lista3))
lista3[0]
# Out:
# 18499
# 18499
# {'id_str': '1144191403557347329',
#  'entities_str': {'hashtags': [{'text': 'Prevencia2019', 'indices': [23, 37]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'LoliRicoG',
#     'name': 'Dolores Rico Garcia',
#     'id': 1484933762,
#     'id_str': '1484933762',
#     'indices': [3, 13]},
#    {'screen_name': 'ginariano',
#     'name': 'Gina Riaño',
#     'id': 413536351,
#     'id_str': '413536351',
#     'indices': [67, 77]},
#    {'screen_name': 'OissSec',
#     'name': 'OISS',
#     'id': 718032769771810800,
#     'id_str': '718032769771810818',
#     'indices': [103, 111]}],
#   'urls': []}}

# %%
# unión de la id
def manejo_lista(id, lista):
    return [(id, l['text']) for l in lista]

# %%
lista_hastags = list(map(lambda x: (manejo_lista(x['id_str'], x['entities_str']['hashtags'])), lista3))

# %%
# función para obtener una lista y guardar en el archivo
def archivo_hashtags(lista):
    archivo = open("data/hashtags_id.csv", "a")
    for l in lista:
        archivo.write("%s|%s\n" % (l[0], l[1]))
    archivo.close()
    return True

# %%
# guardar en el archivo
[archivo_hashtags(l) for l in lista_hastags]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...
